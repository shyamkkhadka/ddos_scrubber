# %% [markdown]
# # Working with OpenINTEL data in pandas/pyarrow
#
# Note that pandas is sufficient for smaller computation loads. OpenINTEL data can be large, and pandas might not be suitable.
# Other tools that we have available at DACS include a Spark based compute cluster, and clickhouseDB.

# %%
import pandas as pd
import requests
import io

# You also need to have the package 'pyarrow' installed!

# %%
# OpenINTEL open data URL, full directory available at: https://openintel.nl/download/
openintel_url = 'https://object.openintel.nl/openintel-public/fdns/basis=toplist/source=tranco/year=2023/month=01/day=01/part-00000-30d969f7-2b36-4163-bb1f-9b641a49e6eb-c000-3af237f7-ff6d-4793-9fdd-44462dc46f4c.gz.parquet'

# %%
# Download the file into memory
response = requests.get(openintel_url)
response.raise_for_status()  # Raise an error if the download fails

# %%
# Read the parquet file into a DataFrame
df = pd.read_parquet(io.BytesIO(response.content), engine="pyarrow")
# print(df.columns)
# Display the first few rows
print(df.columns)
# print(df.head(2))
# Out:
# Index(['query_type', 'query_name', 'response_type', 'response_name',
#        'response_ttl', 'timestamp', 'rtt', 'worker_id', 'status_code',
#        'ad_flag', 'section', 'ip4_address', 'ip6_address', 'country', 'as',
#        'as_full', 'ip_prefix', 'cname_name', 'dname_name', 'mx_address',
#        'mx_preference', 'ns_address', 'txt_text', 'ds_key_tag', 'ds_algorithm',
#        'ds_digest_type', 'ds_digest', 'dnskey_flags', 'dnskey_protocol',
#        'dnskey_algorithm', 'dnskey_pk_rsa_n', 'dnskey_pk_rsa_e',
#        'dnskey_pk_rsa_bitsize', 'dnskey_pk_eccgost_x', 'dnskey_pk_eccgost_y',
#        'dnskey_pk_dsa_t', 'dnskey_pk_dsa_q', 'dnskey_pk_dsa_p',
#        'dnskey_pk_dsa_g', 'dnskey_pk_dsa_y', 'dnskey_pk_eddsa_a',
#        'dnskey_pk_wire', 'nsec_next_domain_name', 'nsec_owner_rrset_types',
#        'nsec3_hash_algorithm', 'nsec3_flags', 'nsec3_iterations', 'nsec3_salt',
#        'nsec3_next_domain_name_hash', 'nsec3_owner_rrset_types',
#        'nsec3param_hash_algorithm', 'nsec3param_flags',
#        'nsec3param_iterations', 'nsec3param_salt', 'spf_text', 'soa_mname',
#        'soa_rname', 'soa_serial', 'soa_refresh', 'soa_retry', 'soa_expire',
#        'soa_minimum', 'rrsig_type_covered', 'rrsig_algorithm', 'rrsig_labels',
#        'rrsig_original_ttl', 'rrsig_signature_inception',
#        'rrsig_signature_expiration', 'rrsig_key_tag', 'rrsig_signer_name',
#        'rrsig_signature', 'cds_key_tag', 'cds_algorithm', 'cds_digest_type',
#        'cds_digest', 'cdnskey_flags', 'cdnskey_protocol', 'cdnskey_algorithm',
#        'cdnskey_pk_rsa_n', 'cdnskey_pk_rsa_e', 'cdnskey_pk_rsa_bitsize',
#        'cdnskey_pk_eccgost_x', 'cdnskey_pk_eccgost_y', 'cdnskey_pk_dsa_t',
#        'cdnskey_pk_dsa_q', 'cdnskey_pk_dsa_p', 'cdnskey_pk_dsa_g',
#        'cdnskey_pk_dsa_y', 'cdnskey_pk_eddsa_a', 'cdnskey_pk_wire',
#        'caa_flags', 'caa_tag', 'caa_value', 'tlsa_usage', 'tlsa_selector',
#        'tlsa_matchtype', 'tlsa_certdata', 'ptr_name'],
#       dtype='object')

# %%
# Show all columns when printing DataFrames
pd.set_option('display.max_columns', None)

# Optionally show more rows too (if needed)
pd.set_option('display.max_rows', 100)

# Query by cname for cloudflare
cname_records = df[(df["response_type"] == "CNAME") & (df["response_name"].str.startswith('cloudflare', na=False)) 
                & (df["cname_name"].str.endswith('cloudflare.net.', na=False))]

# cname for imperva is incapdns.net
# cname_records = df[(df["response_type"] == "CNAME") 
#                 & (df["cname_name"].str.endswith('incapdns.net.', na=False))]

# cname for Akamai is akamai.net
# cname_records = df[(df["response_type"] == "CNAME") 
#                 & (df["cname_name"].str.endswith('akamai.net.', na=False))]

# cname for Ultraddos (Vercara) is ultradns.net
# cname_records = df[(df["response_type"] == "CNAME") 
#                 & (df["cname_name"].str.contains('ultradns', na=False))]

cname_records
# print(f"Len of unique number of domains {len(cname_records['query_name'].unique())}")
# Out:
#          query_type                     query_name response_type  \
# 343855            A                www.yamana.com.         CNAME
# 343863         AAAA                www.yamana.com.         CNAME
# 469262            A  www.farmershomefurniture.com.         CNAME
# 469267         AAAA  www.farmershomefurniture.com.         CNAME
# 485383            A      www.penskeautomotive.com.         CNAME
# ...             ...                            ...           ...
# 12981936       AAAA             www.noblecorp.com.         CNAME
# 13057621          A       www.enproindustries.com.         CNAME
# 13057629       AAAA       www.enproindustries.com.         CNAME
# 13065917          A           www.bwpipelines.com.         CNAME
# 13065926       AAAA           www.bwpipelines.com.         CNAME
#
#                               response_name  response_ttl      timestamp  \
# 343855    cloudflare.cdn.web.prd.q4inc.com.          60.0  1672537041000
# 343863    cloudflare.cdn.web.prd.q4inc.com.          60.0  1672537041000
# 469262            cloudflare.microdinc.com.         600.0  1672536800000
# 469267            cloudflare.microdinc.com.         600.0  1672536800000
# 485383    cloudflare.cdn.web.prd.q4inc.com.          60.0  1672536547000
# ...                                     ...           ...            ...
# 12981936  cloudflare.cdn.web.prd.q4inc.com.          60.0  1672534043000
# 13057621  cloudflare.cdn.web.prd.q4inc.com.          60.0  1672534258000
# 13057629  cloudflare.cdn.web.prd.q4inc.com.          60.0  1672534258000
# 13065917  cloudflare.cdn.web.prd.q4inc.com.          60.0  1672534266000
# 13065926  cloudflare.cdn.web.prd.q4inc.com.          60.0  1672534266000
#
#                rtt   worker_id  status_code  ad_flag section ip4_address  \
# 343855    0.048344  1582299107            0        0     ans        None
# 343863    0.000202  1582299107            0        0     ans        None
# 469262    0.047681  1582299107            0        0     ans        None
# 469267    0.005499  1582299107            0        0     ans        None
# 485383    0.060590  1582299107            0        0     ans        None
# ...            ...         ...          ...      ...     ...         ...
# 12981936  0.000294  1582299107            0        0     ans        None
# 13057621  0.126836  1582299107            0        0     ans        None
# 13057629  0.000110  1582299107            0        0     ans        None
# 13065917  0.034468  1582299107            0        0     ans        None
# 13065926  0.000275  1582299107            0        0     ans        None
#
#          ip6_address country    as as_full ip_prefix  \
# 343855          None    None  None    None      None
# 343863          None    None  None    None      None
# 469262          None    None  None    None      None
# 469267          None    None  None    None      None
# 485383          None    None  None    None      None
# ...              ...     ...   ...     ...       ...
# 12981936        None    None  None    None      None
# 13057621        None    None  None    None      None
# 13057629        None    None  None    None      None
# 13065917        None    None  None    None      None
# 13065926        None    None  None    None      None
#
#                                                  cname_name dname_name  \
# 343855    cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
# 343863    cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
# 469262         cloudflare.microdinc.com.cdn.cloudflare.net.       None
# 469267         cloudflare.microdinc.com.cdn.cloudflare.net.       None
# 485383    cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
# ...                                                     ...        ...
# 12981936  cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
# 13057621  cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
# 13057629  cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
# 13065917  cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
# 13065926  cloudflare.cdn.web.prd.q4inc.com.cdn.cloudflar...       None
#
#          mx_address  mx_preference ns_address txt_text  ds_key_tag  \
# 343855         None            NaN       None     None         NaN
# 343863         None            NaN       None     None         NaN
# 469262         None            NaN       None     None         NaN
# 469267         None            NaN       None     None         NaN
# 485383         None            NaN       None     None         NaN
# ...             ...            ...        ...      ...         ...
# 12981936       None            NaN       None     None         NaN
# 13057621       None            NaN       None     None         NaN
# 13057629       None            NaN       None     None         NaN
# 13065917       None            NaN       None     None         NaN
# 13065926       None            NaN       None     None         NaN
#
#           ds_algorithm  ds_digest_type ds_digest  dnskey_flags  \
# 343855             NaN             NaN      None           NaN
# 343863             NaN             NaN      None           NaN
# 469262             NaN             NaN      None           NaN
# 469267             NaN             NaN      None           NaN
# 485383             NaN             NaN      None           NaN
# ...                ...             ...       ...           ...
# 12981936           NaN             NaN      None           NaN
# 13057621           NaN             NaN      None           NaN
# 13057629           NaN             NaN      None           NaN
# 13065917           NaN             NaN      None           NaN
# 13065926           NaN             NaN      None           NaN
#
#           dnskey_protocol  dnskey_algorithm dnskey_pk_rsa_n dnskey_pk_rsa_e  \
# 343855                NaN               NaN            None            None
# 343863                NaN               NaN            None            None
# 469262                NaN               NaN            None            None
# 469267                NaN               NaN            None            None
# 485383                NaN               NaN            None            None
# ...                   ...               ...             ...             ...
# 12981936              NaN               NaN            None            None
# 13057621              NaN               NaN            None            None
# 13057629              NaN               NaN            None            None
# 13065917              NaN               NaN            None            None
# 13065926              NaN               NaN            None            None
#
#           dnskey_pk_rsa_bitsize dnskey_pk_eccgost_x dnskey_pk_eccgost_y  \
# 343855                      NaN                None                None
# 343863                      NaN                None                None
# 469262                      NaN                None                None
# 469267                      NaN                None                None
# 485383                      NaN                None                None
# ...                         ...                 ...                 ...
# 12981936                    NaN                None                None
# 13057621                    NaN                None                None
# 13057629                    NaN                None                None
# 13065917                    NaN                None                None
# 13065926                    NaN                None                None
#
#          dnskey_pk_dsa_t dnskey_pk_dsa_q dnskey_pk_dsa_p dnskey_pk_dsa_g  \
# 343855              None            None            None            None
# 343863              None            None            None            None
# 469262              None            None            None            None
# 469267              None            None            None            None
# 485383              None            None            None            None
# ...                  ...             ...             ...             ...
# 12981936            None            None            None            None
# 13057621            None            None            None            None
# 13057629            None            None            None            None
# 13065917            None            None            None            None
# 13065926            None            None            None            None
#
#          dnskey_pk_dsa_y dnskey_pk_eddsa_a dnskey_pk_wire  \
# 343855              None              None           None
# 343863              None              None           None
# 469262              None              None           None
# 469267              None              None           None
# 485383              None              None           None
# ...                  ...               ...            ...
# 12981936            None              None           None
# 13057621            None              None           None
# 13057629            None              None           None
# 13065917            None              None           None
# 13065926            None              None           None
#
#          nsec_next_domain_name nsec_owner_rrset_types  nsec3_hash_algorithm  \
# 343855                    None                   None                   NaN
# 343863                    None                   None                   NaN
# 469262                    None                   None                   NaN
# 469267                    None                   None                   NaN
# 485383                    None                   None                   NaN
# ...                        ...                    ...                   ...
# 12981936                  None                   None                   NaN
# 13057621                  None                   None                   NaN
# 13057629                  None                   None                   NaN
# 13065917                  None                   None                   NaN
# 13065926                  None                   None                   NaN
#
#           nsec3_flags  nsec3_iterations nsec3_salt  \
# 343855            NaN               NaN       None
# 343863            NaN               NaN       None
# 469262            NaN               NaN       None
# 469267            NaN               NaN       None
# 485383            NaN               NaN       None
# ...               ...               ...        ...
# 12981936          NaN               NaN       None
# 13057621          NaN               NaN       None
# 13057629          NaN               NaN       None
# 13065917          NaN               NaN       None
# 13065926          NaN               NaN       None
#
#          nsec3_next_domain_name_hash nsec3_owner_rrset_types  \
# 343855                          None                    None
# 343863                          None                    None
# 469262                          None                    None
# 469267                          None                    None
# 485383                          None                    None
# ...                              ...                     ...
# 12981936                        None                    None
# 13057621                        None                    None
# 13057629                        None                    None
# 13065917                        None                    None
# 13065926                        None                    None
#
#           nsec3param_hash_algorithm  nsec3param_flags  nsec3param_iterations  \
# 343855                          NaN               NaN                    NaN
# 343863                          NaN               NaN                    NaN
# 469262                          NaN               NaN                    NaN
# 469267                          NaN               NaN                    NaN
# 485383                          NaN               NaN                    NaN
# ...                             ...               ...                    ...
# 12981936                        NaN               NaN                    NaN
# 13057621                        NaN               NaN                    NaN
# 13057629                        NaN               NaN                    NaN
# 13065917                        NaN               NaN                    NaN
# 13065926                        NaN               NaN                    NaN
#
#          nsec3param_salt spf_text soa_mname soa_rname  soa_serial  \
# 343855              None     None      None      None         NaN
# 343863              None     None      None      None         NaN
# 469262              None     None      None      None         NaN
# 469267              None     None      None      None         NaN
# 485383              None     None      None      None         NaN
# ...                  ...      ...       ...       ...         ...
# 12981936            None     None      None      None         NaN
# 13057621            None     None      None      None         NaN
# 13057629            None     None      None      None         NaN
# 13065917            None     None      None      None         NaN
# 13065926            None     None      None      None         NaN
#
#           soa_refresh  soa_retry  soa_expire  soa_minimum rrsig_type_covered  \
# 343855            NaN        NaN         NaN          NaN               None
# 343863            NaN        NaN         NaN          NaN               None
# 469262            NaN        NaN         NaN          NaN               None
# 469267            NaN        NaN         NaN          NaN               None
# 485383            NaN        NaN         NaN          NaN               None
# ...               ...        ...         ...          ...                ...
# 12981936          NaN        NaN         NaN          NaN               None
# 13057621          NaN        NaN         NaN          NaN               None
# 13057629          NaN        NaN         NaN          NaN               None
# 13065917          NaN        NaN         NaN          NaN               None
# 13065926          NaN        NaN         NaN          NaN               None
#
#           rrsig_algorithm  rrsig_labels  rrsig_original_ttl  \
# 343855                NaN           NaN                 NaN
# 343863                NaN           NaN                 NaN
# 469262                NaN           NaN                 NaN
# 469267                NaN           NaN                 NaN
# 485383                NaN           NaN                 NaN
# ...                   ...           ...                 ...
# 12981936              NaN           NaN                 NaN
# 13057621              NaN           NaN                 NaN
# 13057629              NaN           NaN                 NaN
# 13065917              NaN           NaN                 NaN
# 13065926              NaN           NaN                 NaN
#
#           rrsig_signature_inception  rrsig_signature_expiration  \
# 343855                          NaN                         NaN
# 343863                          NaN                         NaN
# 469262                          NaN                         NaN
# 469267                          NaN                         NaN
# 485383                          NaN                         NaN
# ...                             ...                         ...
# 12981936                        NaN                         NaN
# 13057621                        NaN                         NaN
# 13057629                        NaN                         NaN
# 13065917                        NaN                         NaN
# 13065926                        NaN                         NaN
#
#           rrsig_key_tag rrsig_signer_name rrsig_signature  cds_key_tag  \
# 343855              NaN              None            None          NaN
# 343863              NaN              None            None          NaN
# 469262              NaN              None            None          NaN
# 469267              NaN              None            None          NaN
# 485383              NaN              None            None          NaN
# ...                 ...               ...             ...          ...
# 12981936            NaN              None            None          NaN
# 13057621            NaN              None            None          NaN
# 13057629            NaN              None            None          NaN
# 13065917            NaN              None            None          NaN
# 13065926            NaN              None            None          NaN
#
#           cds_algorithm  cds_digest_type cds_digest  cdnskey_flags  \
# 343855              NaN              NaN       None            NaN
# 343863              NaN              NaN       None            NaN
# 469262              NaN              NaN       None            NaN
# 469267              NaN              NaN       None            NaN
# 485383              NaN              NaN       None            NaN
# ...                 ...              ...        ...            ...
# 12981936            NaN              NaN       None            NaN
# 13057621            NaN              NaN       None            NaN
# 13057629            NaN              NaN       None            NaN
# 13065917            NaN              NaN       None            NaN
# 13065926            NaN              NaN       None            NaN
#
#           cdnskey_protocol  cdnskey_algorithm cdnskey_pk_rsa_n  \
# 343855                 NaN                NaN             None
# 343863                 NaN                NaN             None
# 469262                 NaN                NaN             None
# 469267                 NaN                NaN             None
# 485383                 NaN                NaN             None
# ...                    ...                ...              ...
# 12981936               NaN                NaN             None
# 13057621               NaN                NaN             None
# 13057629               NaN                NaN             None
# 13065917               NaN                NaN             None
# 13065926               NaN                NaN             None
#
#          cdnskey_pk_rsa_e  cdnskey_pk_rsa_bitsize cdnskey_pk_eccgost_x  \
# 343855               None                     NaN                 None
# 343863               None                     NaN                 None
# 469262               None                     NaN                 None
# 469267               None                     NaN                 None
# 485383               None                     NaN                 None
# ...                   ...                     ...                  ...
# 12981936             None                     NaN                 None
# 13057621             None                     NaN                 None
# 13057629             None                     NaN                 None
# 13065917             None                     NaN                 None
# 13065926             None                     NaN                 None
#
#          cdnskey_pk_eccgost_y cdnskey_pk_dsa_t cdnskey_pk_dsa_q  \
# 343855                   None             None             None
# 343863                   None             None             None
# 469262                   None             None             None
# 469267                   None             None             None
# 485383                   None             None             None
# ...                       ...              ...              ...
# 12981936                 None             None             None
# 13057621                 None             None             None
# 13057629                 None             None             None
# 13065917                 None             None             None
# 13065926                 None             None             None
#
#          cdnskey_pk_dsa_p cdnskey_pk_dsa_g cdnskey_pk_dsa_y  \
# 343855               None             None             None
# 343863               None             None             None
# 469262               None             None             None
# 469267               None             None             None
# 485383               None             None             None
# ...                   ...              ...              ...
# 12981936             None             None             None
# 13057621             None             None             None
# 13057629             None             None             None
# 13065917             None             None             None
# 13065926             None             None             None
#
#          cdnskey_pk_eddsa_a cdnskey_pk_wire  caa_flags caa_tag caa_value  \
# 343855                 None            None        NaN    None      None
# 343863                 None            None        NaN    None      None
# 469262                 None            None        NaN    None      None
# 469267                 None            None        NaN    None      None
# 485383                 None            None        NaN    None      None
# ...                     ...             ...        ...     ...       ...
# 12981936               None            None        NaN    None      None
# 13057621               None            None        NaN    None      None
# 13057629               None            None        NaN    None      None
# 13065917               None            None        NaN    None      None
# 13065926               None            None        NaN    None      None
#
#           tlsa_usage  tlsa_selector  tlsa_matchtype tlsa_certdata ptr_name
# 343855           NaN            NaN             NaN          None     None
# 343863           NaN            NaN             NaN          None     None
# 469262           NaN            NaN             NaN          None     None
# 469267           NaN            NaN             NaN          None     None
# 485383           NaN            NaN             NaN          None     None
# ...              ...            ...             ...           ...      ...
# 12981936         NaN            NaN             NaN          None     None
# 13057621         NaN            NaN             NaN          None     None
# 13057629         NaN            NaN             NaN          None     None
# 13065917         NaN            NaN             NaN          None     None
# 13065926         NaN            NaN             NaN          None     None
#
# [180 rows x 98 columns]

# %%
# Look by AS number
as_records = df[(df["as"] == "23454")] # www.almubasher.com.sa
as_records
# as_records_unique = as_records["query_name"].unique()
# as_records_unique
# df[(df["query_name"] == "www.almubasher.com.sa.")]
# Out:
# Empty DataFrame
# Columns: [query_type, query_name, response_type, response_name, response_ttl, timestamp, rtt, worker_id, status_code, ad_flag, section, ip4_address, ip6_address, country, as, as_full, ip_prefix, cname_name, dname_name, mx_address, mx_preference, ns_address, txt_text, ds_key_tag, ds_algorithm, ds_digest_type, ds_digest, dnskey_flags, dnskey_protocol, dnskey_algorithm, dnskey_pk_rsa_n, dnskey_pk_rsa_e, dnskey_pk_rsa_bitsize, dnskey_pk_eccgost_x, dnskey_pk_eccgost_y, dnskey_pk_dsa_t, dnskey_pk_dsa_q, dnskey_pk_dsa_p, dnskey_pk_dsa_g, dnskey_pk_dsa_y, dnskey_pk_eddsa_a, dnskey_pk_wire, nsec_next_domain_name, nsec_owner_rrset_types, nsec3_hash_algorithm, nsec3_flags, nsec3_iterations, nsec3_salt, nsec3_next_domain_name_hash, nsec3_owner_rrset_types, nsec3param_hash_algorithm, nsec3param_flags, nsec3param_iterations, nsec3param_salt, spf_text, soa_mname, soa_rname, soa_serial, soa_refresh, soa_retry, soa_expire, soa_minimum, rrsig_type_covered, rrsig_algorithm, rrsig_labels, rrsig_original_ttl, rrsig_signature_inception, rrsig_signature_expiration, rrsig_key_tag, rrsig_signer_name, rrsig_signature, cds_key_tag, cds_algorithm, cds_digest_type, cds_digest, cdnskey_flags, cdnskey_protocol, cdnskey_algorithm, cdnskey_pk_rsa_n, cdnskey_pk_rsa_e, cdnskey_pk_rsa_bitsize, cdnskey_pk_eccgost_x, cdnskey_pk_eccgost_y, cdnskey_pk_dsa_t, cdnskey_pk_dsa_q, cdnskey_pk_dsa_p, cdnskey_pk_dsa_g, cdnskey_pk_dsa_y, cdnskey_pk_eddsa_a, cdnskey_pk_wire, caa_flags, caa_tag, caa_value, tlsa_usage, tlsa_selector, tlsa_matchtype, tlsa_certdata, ptr_name]
# Index: []

# %%
# Look by NS records
ns_records = df[(df["response_name"].str.contains('ns.cloudflare.com', na = False))]
# ns_records['domain'] = ns_records['response_name'].str.rstrip('.')
ns_records
# Out:
#          query_type            query_name response_type  \
# 12052408          A  www.falconsquad.net.             A
# 12052409          A  www.falconsquad.net.             A
# 12052410          A  www.falconsquad.net.             A
# 12052411          A  www.falconsquad.net.         RRSIG
# 12052413       AAAA  www.falconsquad.net.          AAAA
# 12052414       AAAA  www.falconsquad.net.          AAAA
# 12052415       AAAA  www.falconsquad.net.          AAAA
# 12052416       AAAA  www.falconsquad.net.         RRSIG
#
#                    response_name  response_ttl      timestamp       rtt  \
# 12052408  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.015755
# 12052409  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.015755
# 12052410  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.015755
# 12052411  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.015755
# 12052413  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.005360
# 12052414  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.005360
# 12052415  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.005360
# 12052416  ivy.ns.cloudflare.com.       86353.0  1672538789000  0.005360
#
#            worker_id  status_code  ad_flag section      ip4_address  \
# 12052408  1582299107            0        0     ans  108.162.192.120
# 12052409  1582299107            0        0     ans    172.64.32.120
# 12052410  1582299107            0        0     ans   173.245.58.120
# 12052411  1582299107            0        0     ans             None
# 12052413  1582299107            0        0     ans             None
# 12052414  1582299107            0        0     ans             None
# 12052415  1582299107            0        0     ans             None
# 12052416  1582299107            0        0     ans             None
#
#                       ip6_address country     as  as_full          ip_prefix  \
# 12052408                     None      US  13335  [13335]   108.162.192.0/24
# 12052409                     None      JP  13335  [13335]     172.64.32.0/24
# 12052410                     None      US  13335  [13335]    173.245.58.0/24
# 12052411                     None    None   None     None               None
# 12052413  2606:4700:50::adf5:3a78      US  13335  [13335]  2606:4700:50::/44
# 12052414  2803:f800:50::6ca2:c078      CR  13335  [13335]  2803:f800:50::/45
# 12052415  2a06:98c1:50::ac40:2078      GB  13335  [13335]  2a06:98c1:50::/45
# 12052416                     None    None   None     None               None
#
#          cname_name dname_name mx_address  mx_preference ns_address txt_text  \
# 12052408       None       None       None            NaN       None     None
# 12052409       None       None       None            NaN       None     None
# 12052410       None       None       None            NaN       None     None
# 12052411       None       None       None            NaN       None     None
# 12052413       None       None       None            NaN       None     None
# 12052414       None       None       None            NaN       None     None
# 12052415       None       None       None            NaN       None     None
# 12052416       None       None       None            NaN       None     None
#
#           ds_key_tag  ds_algorithm  ds_digest_type ds_digest  dnskey_flags  \
# 12052408         NaN           NaN             NaN      None           NaN
# 12052409         NaN           NaN             NaN      None           NaN
# 12052410         NaN           NaN             NaN      None           NaN
# 12052411         NaN           NaN             NaN      None           NaN
# 12052413         NaN           NaN             NaN      None           NaN
# 12052414         NaN           NaN             NaN      None           NaN
# 12052415         NaN           NaN             NaN      None           NaN
# 12052416         NaN           NaN             NaN      None           NaN
#
#           dnskey_protocol  dnskey_algorithm dnskey_pk_rsa_n dnskey_pk_rsa_e  \
# 12052408              NaN               NaN            None            None
# 12052409              NaN               NaN            None            None
# 12052410              NaN               NaN            None            None
# 12052411              NaN               NaN            None            None
# 12052413              NaN               NaN            None            None
# 12052414              NaN               NaN            None            None
# 12052415              NaN               NaN            None            None
# 12052416              NaN               NaN            None            None
#
#           dnskey_pk_rsa_bitsize dnskey_pk_eccgost_x dnskey_pk_eccgost_y  \
# 12052408                    NaN                None                None
# 12052409                    NaN                None                None
# 12052410                    NaN                None                None
# 12052411                    NaN                None                None
# 12052413                    NaN                None                None
# 12052414                    NaN                None                None
# 12052415                    NaN                None                None
# 12052416                    NaN                None                None
#
#          dnskey_pk_dsa_t dnskey_pk_dsa_q dnskey_pk_dsa_p dnskey_pk_dsa_g  \
# 12052408            None            None            None            None
# 12052409            None            None            None            None
# 12052410            None            None            None            None
# 12052411            None            None            None            None
# 12052413            None            None            None            None
# 12052414            None            None            None            None
# 12052415            None            None            None            None
# 12052416            None            None            None            None
#
#          dnskey_pk_dsa_y dnskey_pk_eddsa_a dnskey_pk_wire  \
# 12052408            None              None           None
# 12052409            None              None           None
# 12052410            None              None           None
# 12052411            None              None           None
# 12052413            None              None           None
# 12052414            None              None           None
# 12052415            None              None           None
# 12052416            None              None           None
#
#          nsec_next_domain_name nsec_owner_rrset_types  nsec3_hash_algorithm  \
# 12052408                  None                   None                   NaN
# 12052409                  None                   None                   NaN
# 12052410                  None                   None                   NaN
# 12052411                  None                   None                   NaN
# 12052413                  None                   None                   NaN
# 12052414                  None                   None                   NaN
# 12052415                  None                   None                   NaN
# 12052416                  None                   None                   NaN
#
#           nsec3_flags  nsec3_iterations nsec3_salt  \
# 12052408          NaN               NaN       None
# 12052409          NaN               NaN       None
# 12052410          NaN               NaN       None
# 12052411          NaN               NaN       None
# 12052413          NaN               NaN       None
# 12052414          NaN               NaN       None
# 12052415          NaN               NaN       None
# 12052416          NaN               NaN       None
#
#          nsec3_next_domain_name_hash nsec3_owner_rrset_types  \
# 12052408                        None                    None
# 12052409                        None                    None
# 12052410                        None                    None
# 12052411                        None                    None
# 12052413                        None                    None
# 12052414                        None                    None
# 12052415                        None                    None
# 12052416                        None                    None
#
#           nsec3param_hash_algorithm  nsec3param_flags  nsec3param_iterations  \
# 12052408                        NaN               NaN                    NaN
# 12052409                        NaN               NaN                    NaN
# 12052410                        NaN               NaN                    NaN
# 12052411                        NaN               NaN                    NaN
# 12052413                        NaN               NaN                    NaN
# 12052414                        NaN               NaN                    NaN
# 12052415                        NaN               NaN                    NaN
# 12052416                        NaN               NaN                    NaN
#
#          nsec3param_salt spf_text soa_mname soa_rname  soa_serial  \
# 12052408            None     None      None      None         NaN
# 12052409            None     None      None      None         NaN
# 12052410            None     None      None      None         NaN
# 12052411            None     None      None      None         NaN
# 12052413            None     None      None      None         NaN
# 12052414            None     None      None      None         NaN
# 12052415            None     None      None      None         NaN
# 12052416            None     None      None      None         NaN
#
#           soa_refresh  soa_retry  soa_expire  soa_minimum rrsig_type_covered  \
# 12052408          NaN        NaN         NaN          NaN               None
# 12052409          NaN        NaN         NaN          NaN               None
# 12052410          NaN        NaN         NaN          NaN               None
# 12052411          NaN        NaN         NaN          NaN                  A
# 12052413          NaN        NaN         NaN          NaN               None
# 12052414          NaN        NaN         NaN          NaN               None
# 12052415          NaN        NaN         NaN          NaN               None
# 12052416          NaN        NaN         NaN          NaN               AAAA
#
#           rrsig_algorithm  rrsig_labels  rrsig_original_ttl  \
# 12052408              NaN           NaN                 NaN
# 12052409              NaN           NaN                 NaN
# 12052410              NaN           NaN                 NaN
# 12052411             13.0           4.0             86353.0
# 12052413              NaN           NaN                 NaN
# 12052414              NaN           NaN                 NaN
# 12052415              NaN           NaN                 NaN
# 12052416             13.0           4.0             86353.0
#
#           rrsig_signature_inception  rrsig_signature_expiration  \
# 12052408                        NaN                         NaN
# 12052409                        NaN                         NaN
# 12052410                        NaN                         NaN
# 12052411               1.672449e+09                1.672629e+09
# 12052413                        NaN                         NaN
# 12052414                        NaN                         NaN
# 12052415                        NaN                         NaN
# 12052416               1.672449e+09                1.672629e+09
#
#           rrsig_key_tag rrsig_signer_name  \
# 12052408            NaN              None
# 12052409            NaN              None
# 12052410            NaN              None
# 12052411        34505.0   cloudflare.com.
# 12052413            NaN              None
# 12052414            NaN              None
# 12052415            NaN              None
# 12052416        34505.0   cloudflare.com.
#
#                                             rrsig_signature  cds_key_tag  \
# 12052408                                               None          NaN
# 12052409                                               None          NaN
# 12052410                                               None          NaN
# 12052411  a378bf0700eef518a8abac064cd34959c0c306d53a78d6...          NaN
# 12052413                                               None          NaN
# 12052414                                               None          NaN
# 12052415                                               None          NaN
# 12052416  34f415eaa6b13f1394a3829210a24d171a5d069be2474c...          NaN
#
#           cds_algorithm  cds_digest_type cds_digest  cdnskey_flags  \
# 12052408            NaN              NaN       None            NaN
# 12052409            NaN              NaN       None            NaN
# 12052410            NaN              NaN       None            NaN
# 12052411            NaN              NaN       None            NaN
# 12052413            NaN              NaN       None            NaN
# 12052414            NaN              NaN       None            NaN
# 12052415            NaN              NaN       None            NaN
# 12052416            NaN              NaN       None            NaN
#
#           cdnskey_protocol  cdnskey_algorithm cdnskey_pk_rsa_n  \
# 12052408               NaN                NaN             None
# 12052409               NaN                NaN             None
# 12052410               NaN                NaN             None
# 12052411               NaN                NaN             None
# 12052413               NaN                NaN             None
# 12052414               NaN                NaN             None
# 12052415               NaN                NaN             None
# 12052416               NaN                NaN             None
#
#          cdnskey_pk_rsa_e  cdnskey_pk_rsa_bitsize cdnskey_pk_eccgost_x  \
# 12052408             None                     NaN                 None
# 12052409             None                     NaN                 None
# 12052410             None                     NaN                 None
# 12052411             None                     NaN                 None
# 12052413             None                     NaN                 None
# 12052414             None                     NaN                 None
# 12052415             None                     NaN                 None
# 12052416             None                     NaN                 None
#
#          cdnskey_pk_eccgost_y cdnskey_pk_dsa_t cdnskey_pk_dsa_q  \
# 12052408                 None             None             None
# 12052409                 None             None             None
# 12052410                 None             None             None
# 12052411                 None             None             None
# 12052413                 None             None             None
# 12052414                 None             None             None
# 12052415                 None             None             None
# 12052416                 None             None             None
#
#          cdnskey_pk_dsa_p cdnskey_pk_dsa_g cdnskey_pk_dsa_y  \
# 12052408             None             None             None
# 12052409             None             None             None
# 12052410             None             None             None
# 12052411             None             None             None
# 12052413             None             None             None
# 12052414             None             None             None
# 12052415             None             None             None
# 12052416             None             None             None
#
#          cdnskey_pk_eddsa_a cdnskey_pk_wire  caa_flags caa_tag caa_value  \
# 12052408               None            None        NaN    None      None
# 12052409               None            None        NaN    None      None
# 12052410               None            None        NaN    None      None
# 12052411               None            None        NaN    None      None
# 12052413               None            None        NaN    None      None
# 12052414               None            None        NaN    None      None
# 12052415               None            None        NaN    None      None
# 12052416               None            None        NaN    None      None
#
#           tlsa_usage  tlsa_selector  tlsa_matchtype tlsa_certdata ptr_name
# 12052408         NaN            NaN             NaN          None     None
# 12052409         NaN            NaN             NaN          None     None
# 12052410         NaN            NaN             NaN          None     None
# 12052411         NaN            NaN             NaN          None     None
# 12052413         NaN            NaN             NaN          None     None
# 12052414         NaN            NaN             NaN          None     None
# 12052415         NaN            NaN             NaN          None     None
# 12052416         NaN            NaN             NaN          None     None

# %%
# Process the OpenINTEL data
tranco_a_df = df[df['response_type'] == 'A'] # Filter on DNS response type A
tranco_a_ip4_df = tranco_a_df['ip4_address']  # Get the column we want

tranco_a_ip4_nparray = tranco_a_ip4_df.unique()  # Only grab unique values

tranco_a_df['domain'] = tranco_a_df['response_name'].str.rstrip('.')

tranco_domain_a_df = tranco_a_df[['domain', 'ip4_address']].copy()
unique_tranco_domain_a_df = tranco_domain_a_df.drop_duplicates()
 # Sometimes duplications are found.
# Print count
print('Total IP4 addresses found: %s and unique addresses are %s' %((len(tranco_a_ip4_df), len(tranco_a_ip4_nparray))))

# %%
unique_tranco_domain_a_df.to_csv("../data/tranco-1m/openintel_domain_a_record_2023.csv", index=False)

# %%
# Save ranks of tranco domains in a csv file: tranco_domains_with_rank.csv
import csv

# Load domains and assign ranks
rank_dict = {}
with open("../data/tranco-1m/top-1m.txt", "r", encoding="utf-8") as f, open("../data/tranco-1m/tranco_domains_with_rank.csv", "w") as out:
    writer = csv.writer(out)
    writer.writerow(["domain", "rank"])
    
    for rank, domain in enumerate(f, start=1):  # Auto-assign rank
        domain = domain.strip()
        rank_dict[domain] = str(rank)
        writer.writerow([domain, rank])

# %%
# Find ranks of tranco 1M domains with their A records (IP address/es) and save it into a file.
import csv
import pandas as pd

# 1. Read tranco_domain_a_df that has domain name and ranks: openintel_domain_a_record
# 2. Join it with tranco_domains_with_rank
df1 = pd.read_csv("../data/tranco-1m/tranco_domains_with_rank_2023.csv")
df2 = pd.read_csv("../data/tranco-1m/openintel_domain_a_record_2023.csv")
df3 = df1.merge(df2, how='left', on='domain')

df3.to_csv("../data/tranco-1m/openintel_tranco_resolved_with_rank_2023.csv", index=False)

# %%
# Find the number of matched IP addresses 

# Compare the ip addresses with the protected prefixes using pytricia loop
import pandas as pd
import ipaddress
import pytricia


def build_prefix_trees(prefix_list):
    """Builds two Patricia Tries: one for IPv4 and one for IPv6."""
    pt_v4 = pytricia.PyTricia()
    pt_v6 = pytricia.PyTricia()

    for prefix in prefix_list:
        network = ipaddress.ip_network(prefix)
        if network.version == 4:

            pt_v4[prefix] = True
        else:
            pt_v6[prefix] = True

    return pt_v4, pt_v6

def count_covered_ips(ip_list, pt_v4, pt_v6):
    """Counts how many IPs are covered by the prefixes in the Patricia Tries."""
    count = 0
    for ip in ip_list:
        ip_obj = ipaddress.ip_address(ip)
        if ip_obj.version == 4 and pt_v4.get(ip):
            count += 1
        elif ip_obj.version == 6 and pt_v6.get(ip):
            count += 1

    return count


def get_covered_ips(ip_list, pt_v4, pt_v6):
    """Returns the list of IPs covered by prefixes in the Patricia Trie."""
    covered_ips = []
    for ip in ip_list:
        ip_obj = ipaddress.ip_address(ip)
        if ip_obj.version == 4 and pt_v4.get(ip):
            covered_ips.append(ip)
        elif ip_obj.version == 6 and pt_v6.get(ip):
            covered_ips.append(ip)
#     covered_ips = [ip for ip in ip_list if prefix_tree.get(ip)]
    return covered_ips



# Protected prefixes lists using all five scrubberscovered_count
df = pd.read_csv("../data/customers_prefixes_scrubber_all_2023.csv") 
protected_prefixes = df["prefix"].tolist()

# Openintel list of IP addresses
df = pd.read_csv("../data/tranco-1m/openintel_tranco_resolved_with_rank_2023.csv") 
df_cleaned = df.dropna()

tranco_ip_addresses = df_cleaned["ip4_address"].unique()

# Build separate prefix trees for IPv4 and IPv6
pt_v4, pt_v6 = build_prefix_trees(protected_prefixes)

# Find the number of IPs covered
covered_count = count_covered_ips(tranco_ip_addresses, pt_v4, pt_v6)

# Find the IPs covered
covered_ips = get_covered_ips(tranco_ip_addresses, pt_v4, pt_v6)


# Save covered ips in a .txt file.
with open("../data/tranco-1m/openintel_tranco_scrubber_covered_ip_2023.txt", "w", encoding="utf-8") as f:
    for ip in covered_ips:
        f.write(f"{ip}\n")
print(f"Number of IPs protected by the five scrubber's protected prefixes is: {len(covered_ips)} and IPs saved in openintel_tranco_scrubber_covered_ip_2023.txt")

# %%
# Find ranks of tranco 1M domains with their A records (IP address/es) and save it into a file.
import csv

covered_ips = []
# Parse massdns results
with open("../data/tranco-1m/openintel_tranco_scrubber_covered_ip_2023.txt", "r", encoding="utf-8") as f:
    for line in f:
        ip = line.strip("\n")
        covered_ips.append(ip)
        
# Convert it into a dataframe with column name ipv4_address
df1 = pd.DataFrame(covered_ips, columns=['ip4_address'])

df2 = pd.read_csv("../data/tranco-1m/openintel_tranco_resolved_with_rank_2023.csv")

# df3 = df2.merge(df1, how='inner', on='ip4_address')
        
    
result = df1.merge(df2, on='ip4_address', how='inner')
result.to_csv("../data/tranco-1m/openintel_ip_domains_ranks_2023.csv", index=False)

print("%s number of domains are protected. \n" %len(result))

# %%
result.sort_values("rank", ascending=False)
